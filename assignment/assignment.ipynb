# %% [markdown]
# # Assignment: Data Wrangling
# ## `! git clone https://github.com/DS3001/wrangling`
# ## Do Q2, and one of Q1 or Q3.

# %% [markdown]
# **Q1.** Open the "tidy_data.pdf" document in the repo, which is a paper called Tidy Data by Hadley Wickham.
#
#   1. Read the abstract. What is this paper about?
#   2. Read the introduction. What is the "tidy data standard" intended to accomplish?
#   3. Read the intro to section 2. What does this sentence mean: "Like families, tidy datasets are all alike but every messy dataset is messy in its own way." What does this sentence mean: "For a given dataset, it’s usually easy to figure out what are observations and what are variables, but it is surprisingly difficult to precisely define variables and observations in general."
#   4. Read Section 2.2. How does Wickham define values, variables, and observations?
#   5. How is "Tidy Data" defined in section 2.3?
#   6. Read the intro to Section 3 and Section 3.1. What are the 5 most common problems with messy datasets? Why are the data in Table 4 messy? What is "melting" a dataset?
#   7. Why, specifically, is table 11 messy but table 12 tidy and "molten"?
#   8. Read Section 6. What is the "chicken-and-egg" problem with focusing on tidy data? What does Wickham hope happens in the future with further work on the subject of data wrangling?

# %% [markdown]
# **Q2.** This question provides some practice cleaning variables which have common problems.
# 1. Numeric variable: For `./data/airbnb_hw.csv`, clean the `Price` variable as well as you can, and explain the choices you make. How many missing values do you end up with? (Hint: What happens to the formatting when a price goes over 999 dollars, say from 675 to 1,112?)
# 2. Categorical variable: For the `./data/sharks.csv` data covered in the lecture, clean the "Type" variable as well as you can, and explain the choices you make.
# 3. Dummy variable: For the pretrial data covered in the lecture, clean the `WhetherDefendantWasReleasedPretrial` variable as well as you can, and, in particular, replace missing values with `np.nan`.
# 4. Missing values, not at random: For the pretrial data covered in the lecture, clean the `ImposedSentenceAllChargeInContactEvent` variable as well as you can, and explain the choices you make. (Hint: Look at the `SentenceTypeAllChargesAtConvictionInContactEvent` variable.)

# %%
import pandas as pd
import numpy as np

# %%
# QUESTION 1

# %%
df = pd.read_csv('./data/airbnb_hw.csv',low_memory=False)
df.head()
# Out:
#     Host Id Host Since                                Name Neighbourhood   \
# 0   5162530        NaN     1 Bedroom in Prime Williamsburg       Brooklyn
# 1  33134899        NaN     Sunny, Private room in Bushwick       Brooklyn
# 2  39608626        NaN                Sunny Room in Harlem      Manhattan
# 3       500  6/26/2008  Gorgeous 1 BR with Private Balcony      Manhattan
# 4       500  6/26/2008            Trendy Times Square Loft      Manhattan
#
#   Property Type  Review Scores Rating (bin)        Room Type  Zipcode  Beds  \
# 0     Apartment                         NaN  Entire home/apt  11249.0   1.0
# 1     Apartment                         NaN     Private room  11206.0   1.0
# 2     Apartment                         NaN     Private room  10032.0   1.0
# 3     Apartment                         NaN  Entire home/apt  10024.0   3.0
# 4     Apartment                        95.0     Private room  10036.0   3.0
#
# ...

# %%
df['Price'].unique() 
# The price formatting includes a comma to separate the thousands place when the price goes over 999 dollars
# Out:
# array(['145', '37', '28', '199', '549', '149', '250', '90', '270', '290',
#        '170', '59', '49', '68', '285', '75', '100', '150', '700', '125',
#        '175', '40', '89', '95', '99', '499', '120', '79', '110', '180',
#        '143', '230', '350', '135', '85', '60', '70', '55', '44', '200',
#        '165', '115', '74', '84', '129', '50', '185', '80', '190', '140',
#        '45', '65', '225', '600', '109', '1,990', '73', '240', '72', '105',
#        '155', '160', '42', '132', '117', '295', '280', '159', '107', '69',
#        '239', '220', '399', '130', '375', '585', '275', '139', '260',
#        '35', '133', '300', '289', '179', '98', '195', '29', '27', '39',
#        '249', '192', '142', '169', '1,000', '131', '138', '113', '122',
#        '329', '101', '475', '238', '272', '308', '126', '235', '315',
#        '248', '128', '56', '207', '450', '215', '210', '385', '445',
#        '136', '247', '118', '77', '76', '92', '198', '205', '299', '222',
# ...

# %%
# For price- remove the comma, turn it to a numeric data
price = df['Price'] 
price = price.str.replace(',','') 
price = pd.to_numeric(price,errors='coerce')
print(price.unique())
# Out:
# [  145    37    28   199   549   149   250    90   270   290   170    59
#     49    68   285    75   100   150   700   125   175    40    89    95
#     99   499   120    79   110   180   143   230   350   135    85    60
#     70    55    44   200   165   115    74    84   129    50   185    80
#    190   140    45    65   225   600   109  1990    73   240    72   105
#    155   160    42   132   117   295   280   159   107    69   239   220
#    399   130   375   585   275   139   260    35   133   300   289   179
#     98   195    29    27    39   249   192   142   169  1000   131   138
#    113   122   329   101   475   238   272   308   126   235   315   248
#    128    56   207   450   215   210   385   445   136   247   118    77
#     76    92   198   205   299   222   245   104   153   349   114   320
#    292   226   420   500   325   307    78   265   108   123   189    32
#     58    86   219   800   335    63   229   425    67    87  1200   158
# ...

# %%
# Check if any more null price data (ends up with 0)
sum(price.isnull())
# Out:
# 0

# %%
# QUESTION 2 - For the `./data/sharks.csv` data covered in the lecture, clean the "Type" variable as well as you can, and explain the choices you make.

# %%
df = pd.read_csv('./data/sharks.csv',low_memory=False)
df.head()
# Out:
#    index   Case Number                  Date    Year        Type      Country  \
# 0      0    2020.02.05           05-Feb-2020  2020.0  Unprovoked          USA
# 1      1  2020.01.30.R  Reported 30-Jan-2020  2020.0    Provoked      BAHAMAS
# 2      2    2020.01.17           17-Jan-2020  2020.0  Unprovoked    AUSTRALIA
# 3      3    2020.01.16           16-Jan-2020  2020.0  Unprovoked  NEW ZEALAND
# 4      4    2020.01.13           13-Jan-2020  2020.0  Unprovoked          USA
#
#               Area               Location                  Activity  \
# 0             Maui                    NaN  Stand-Up Paddle boarding
# 1           Exumas                    NaN                  Floating
# 2  New South Wales          Windang Beach                   Surfing
# 3        Southland            Oreti Beach                   Surfing
# 4   North Carolina  Rodanthe, Dare County                   Surfing
#
#               Name  ... Unnamed: 246 Unnamed: 247 Unnamed: 248 Unnamed: 249  \
# ...

# %%
# df['Type'].value_counts()

type = df['Type']
type.value_counts()
# check for all types, a lot of these are similar... like boat, boating, boatomg?, and sea disaster can all fall under the watercraft category
# also a lot of uncertain/unclean data
# Out:
# Type
# Unprovoked    4716
# Provoked       593
# Watercraft     583
# Name: count, dtype: int64

# %%
type = type.replace(['Boat', 'Boating', 'Boatomg', 'Sea Disaster'], 'Watercraft') # combine all water related data to a single watercraft type
type = type.replace(['Invalid', 'Questionable', 'Unconfirmed', 'Unverified', 'Under investigation'], np.nan) # combine all uncertain/unclean data to NaN

type.value_counts()

df['Type'] = type # Replace the 'Type' variable with the cleaned version

df['Type'].value_counts()
# sum(df['Type'].isnull())
# Out:
# Type
# Unprovoked    4716
# Provoked       593
# Watercraft     583
# Name: count, dtype: int64

# %%
fatal = df['Fatal (Y/N)']
fatal.value_counts() # very unclean data with the fatal column... there's even random gender/year data in here
# Out:
# Fatal (Y/N)
# N          4439
# Y          1400
# UNKNOWN      71
# F             2
# M             1
# 2017          1
# y             1
# Name: count, dtype: int64

# %%
fatal = fatal.replace(['UNKNOWN', 'F', 'M', '2017'], np.nan) # replace all unclean/unknown data with nan
fatal = fatal.replace('y', 'Y') # replace that lowercase y to capital Y
fatal.value_counts()

df['Fatal (Y/N)'] = fatal
df['Fatal (Y/N)'].value_counts()
# Out:
# Fatal (Y/N)
# N    4439
# Y    1401
# Name: count, dtype: int64

# %%
# QUESTION 3 - Dummy variable: For the pretrial data covered in the lecture, clean the WhetherDefendantWasReleasedPretrial variable as well as you can,
# and, in particular, replace missing values with np.nan.

# %%
url = 'http://www.vcsc.virginia.gov/pretrialdataproject/October%202017%20Cohort_Virginia%20Pretrial%20Data%20Project_Deidentified%20FINAL%20Update_10272021.csv'
df = pd.read_csv(url,low_memory=False)
df.head()
# Out:
#   InternalStudyID REQ_REC# Defendant_Sex Defendant_Race Defendant_BirthYear  \
# 0        ADI00001        1             M              W                1986
# 1        ADI00007        3             M              B                1956
# 2        ADI00008        4             M              W                1990
# 3        CDI00036        6             M              B                1989
# 4        CDI00038        7             F              W                1988
#
#   Defendant_Age  Defendant_AgeGroup Defendant_AgeatCurrentArrest  \
# 0            31                   3                           31
# 1            60                   6                           60
# 2            27                   3                           27
# 3            27                   3                           27
# 4            28                   3                           28
#
#    Defendant_AttorneyTypeAtCaseClosure  Defendant_IndigencyStatus  ...  \
# ...

# %%
release = df['WhetherDefendantWasReleasedPretrial']
release.value_counts()
# Out:
# WhetherDefendantWasReleasedPretrial
# 1    19154
# 0     3801
# 9       31
# Name: count, dtype: int64

# %%
# According to the PDF, this is the Label Code:
# Not released 0
# Released 1
# Unclear 9
# So I need to clean it below based on that

release = release.replace(9, np.nan) #replace 9 with nan
release.value_counts() # check to see if it worked
# Out:
# WhetherDefendantWasReleasedPretrial
# 1.0    19154
# 0.0     3801
# Name: count, dtype: int64

# %%
# QUESTION 4 - Missing values, not at random: For the pretrial data covered in the lecture, clean the ImposedSentenceAllChargeInContactEvent variable 
# as well as you can, and explain the choices you make. (Hint: Look at the SentenceTypeAllChargesAtConvictionInContactEvent variable.)

# %%
url = 'http://www.vcsc.virginia.gov/pretrialdataproject/October%202017%20Cohort_Virginia%20Pretrial%20Data%20Project_Deidentified%20FINAL%20Update_10272021.csv'
df = pd.read_csv(url,low_memory=False)
df.head()
# Out:
#   InternalStudyID REQ_REC# Defendant_Sex Defendant_Race Defendant_BirthYear  \
# 0        ADI00001        1             M              W                1986
# 1        ADI00007        3             M              B                1956
# 2        ADI00008        4             M              W                1990
# 3        CDI00036        6             M              B                1989
# 4        CDI00038        7             F              W                1988
#
#   Defendant_Age  Defendant_AgeGroup Defendant_AgeatCurrentArrest  \
# 0            31                   3                           31
# 1            60                   6                           60
# 2            27                   3                           27
# 3            27                   3                           27
# 4            28                   3                           28
#
#    Defendant_AttorneyTypeAtCaseClosure  Defendant_IndigencyStatus  ...  \
# ...

# %%
sentence_length = df['ImposedSentenceAllChargeInContactEvent']
sentence_type = df['SentenceTypeAllChargesAtConvictionInContactEvent']
print(sentence_length.unique()) # weird, ' ' is considered a value
# Out:
# [' ' '60' '12' '.985626283367556' '36' '6' '24' '5.91375770020534' '120'
#  '72' '11.9917864476386' '0' '2.95687885010267' '84' '108' '300' '240'
#  '180' '4' '96' '2' '54' '.328542094455852' '44' '5' '115' '132' '48'
#  '258' '34' '76' '.164271047227926' '.131416837782341' '111' '9' '3'
#  '1.97125256673511' '36.9856262833676' '.0657084188911704'
#  '35.4928131416838' '106.492813141684' '8' '35' '18.3141683778234' '480'
#  '32' '93' '234' '732' '1.16427104722793' '4.6570841889117' '21' '7'
#  '4.49281314168378' '18' '600' '43.1642710472279' '179' '52' '30' '20'
#  '192' '702' '14' '55' '53' '11.9055441478439' '114' '35.0061601642711'
#  '68' '.657084188911704' '46.6242299794661' '102' '65' '200' '57'
#  '24.3285420944559' '12.1642710472279' '117' '81.4928131416838'
#  '22.4928131416838' '1980' '3.6570841889117' '56' '10' '2.79260780287474'
#  '1' '47' '22' '1500' '40' '284' '11' '118' '42' '162' '156'
#  '47.2956878850103' '105' '51' '246' '29' '75' '324' '360'
# ...

# %%
sentence_length = pd.to_numeric(sentence_length,errors='coerce') # change all data to numeric
print( np.sum(sentence_length.isnull()),'\n') # 9053 null data points...

# According to pdf, cat 4 is dismissed cases and cat 9 is na
sentence_length = sentence_length.mask(sentence_type == 4, 0) # replace cat 4 with 0
sentence_length = sentence_length.mask(sentence_type == 9, np.nan) # replace cat 9 with nan

# Make new dummy variable to lessen the number of NAs
NA_sentence_length = sentence_length.isnull()
# print( pd.crosstab(NA_sentence_length, sentence_type), '\n')
print( np.sum(NA_sentence_length),'\n') # 274 now

df['ImposedSentenceAllChargeInContactEvent'] = sentence_length
# Out:
# 9053
#
# 274

# %% [markdown]
# **Q3.** Many important datasets contain a race variable, typically limited to a handful of values often including Black, White, Asian, Latino, and Indigenous. This question looks at data gathering efforts on this variable by the U.S. Federal government.
#
# 1. How did the most recent US Census gather data on race?
# > The most recent US Census gathered data on race through self-identification questions regarding race and ethnicity. People can choose to report one or multiple race group, and people of any race may be of any ethnic origin.
#
# 2. Why do we gather these data? What role do these kinds of data play in politics and society? Why does data quality matter?
# > The US Census gather these data to help governments and communities enforce antidiscrimination laws, regulations, and policies. Data quality is important in this case because inaccurate data can misrepresent the population, which can lead to unequal distribucation of resources and uneffective anti-discrimination laws. To address disparities, accurate and high-quality data is important.
#
# 3. Please provide a constructive criticism of how the Census was conducted: What was done well? What do you think was missing? How should future large scale surveys be adjusted to best reflect the diversity of the population? Could some of the Census' good practices be adopted more widely to gather richer and more useful data?
# > Strength of the Census: It allowed people to write in their specific racial or ethnic backgrounds, which makes it flexible and efficient to gather detailed data on the diversity within our community as well as multi-racial individuals.
# > Weakness/What was missing of the Census: It seems like there is still a large response for other races, which results in the lack of specific identification of the diversity within our community. This approach oversimplies the racial identity of individuals who may be multi-racial.
# > Future large scale surveys can increase the set of categories that represents multi-racial individuals as well as outreach that supports underrepresented population groups. These practices as well as its current practices can result in richer and more useful data.
#
# 4. How did the Census gather data on sex and gender? Please provide a similar constructive criticism of their practices.
# > The Census gathers data on sex and gender with just a question that asks for the individual's sex/gender. This is more complicated in the recent times with the rise of other gender identifications, such as non-binary, transgender, and other types of genders that does not fit within the traditional data. The strength for this would be the simplicity of keeping data simple and understandable. However, the weakness would also be that this does not reflect the various gender options out there. A way to best reflect the diversity of the population would probably be to include more options, such as "non-binary" and "transgender", in which they can select more options about their gender identification.
#
# 5. When it comes to cleaning data, what concerns do you have about protected characteristics like sex, gender, sexual identity, or race? What challenges can you imagine arising when there are missing values? What good or bad practices might people adopt, and why?
# > When dealing with sensitive and protected characteristics data, there may be some concerns over the accuracy and the representation of that data. Misclassification or oversimplification of identity characteristics like gender or race can lead to significant societal problems. Privacy is also important, particularly in protecting personal information related to sexual orientation or gender identity, as those could be sensitive to people. Additionally, bias can emerge during the data cleaning process when looking at the various data values, especially when the standard categories are imposed that removes the actual complexity of people's identities in the recent age. This is problematic when individuals' responses are forced into the specific categories that does not reflect their lived experiences or personal beliefs. If there are missing data, imputing values based on patterns or assumptions could result in further risks, because assuming a person's race based on their name or the likes can reinforce stereotypes and lead to misrepresentation.
#
# 6. Suppose someone invented an algorithm to impute values for protected characteristics like race, gender, sex, or sexuality. What kinds of concerns would you have?
# > Using an algorithm to impute values for protected characteristics may raise many concerns. For example, it could result in incomplete data that can influence the stereotypes and biases that we have against those data. This can result in misrepresentation and damage our self-identification. An algorithm can also introduce potential privacy concerns, because we won't know the security level of such algorithm. Potential leaks in data may lead to privacy concerns that may affect some individuals, especially in cases where anonymity is in effect.
